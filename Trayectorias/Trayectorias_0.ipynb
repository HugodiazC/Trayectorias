# %%
# Packages for analysis
import pandas as pd
import numpy as np
from sklearn import svm

# Packages for visuals
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(font_scale=1.2)

# Allows charts to appear in the notebook
# %matplotlib inline

# Pickle package
import pickle

# %%
# Read dataset
data = pd.read_csv('Dataset_T.csv')
data
# Out:
#                                           PLAN_INTERES      ID Gender  Age  \
# 0                           Especialidad en Innovación  274576      M   44
# 1                           Especialidad en Innovación  340962      M   43
# 2                           Especialidad en Innovación  370676      F   43
# 3                           Especialidad en Innovación  420035      M   43
# 4                           Especialidad en Innovación  434520      F   30
# ..                                                 ...     ...    ...  ...
# 144                              Maestría en Educación  601396      F   32
# 145                              Maestría en Educación  751888      F   42
# 146  Maestría en Gestión de Tecnologías de Información  345549      F   34
# 147  Maestría en Gestión de Tecnologías de Información  800322      M   41
# 148  Maestría en Gestión de Tecnologías de Información  823845      M   42
#
# ...

# %%
from matplotlib.ticker import PercentFormatter

# %%
frec = pd.value_counts(data['CANAL'])
frec
# Out:
# Digital - Facebook     80
# Presencial - Campus    30
# Digital - Google       26
# Call Center            13
# Name: CANAL, dtype: int64

# %%
frec2 = pd.value_counts(data['MOTIVO_DESCARTE'])
frec2
# Out:
# Costo                  44
# Duración               41
# Plan de estudios       31
# Prefiere presencial    19
# Eligio otra escuela    14
# Name: MOTIVO_DESCARTE, dtype: int64

# %%
mean_prom = data['PROMEDIO'].mean()
mean_prom
# Out:
# 79.20805369127517

# %%
frec3 = pd.value_counts(data['POR_OFERTADO'])
frec3
# Out:
# 40    47
# 30    32
# 0     24
# 50    12
# 35    11
# 20    11
# 45     6
# 60     3
# 15     2
# 25     1
# Name: POR_OFERTADO, dtype: int64

# %%
sns.lmplot('POR_OFERTADO', 'PROMEDIO', data=data, hue='NIVEL_INTERES',
           palette='Set1', fit_reg=False, scatter_kws={"s": 70});
# Out:
# C:\Users\L01506162\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('POR_OFERTADO', 'PROMEDIO', data=data, hue='NIVEL_INTERES',
           palette='Set1', scatter_kws={"s": 70});
# Out:
# C:\Users\L01506162\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('POR_OFERTADO', 'PROMEDIO', data=data, hue='CANAL',
           palette='Set1', fit_reg=False, scatter_kws={"s": 70});
# Out:
# C:\Users\L01506162\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('POR_OFERTADO', 'Age', data=data, hue='MOTIVO_DESCARTE',
           palette='Set1', scatter_kws={"s": 70});
# Out:
# C:\Users\L01506162\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('POR_OFERTADO', 'PROMEDIO', data=data, hue='MOTIVO_DESCARTE',
           palette='Set1', scatter_kws={"s": 70});
# Out:
# C:\Users\L01506162\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('POR_OFERTADO', 'PROMEDIO', data=data, hue='PLAN_INTERES',
           palette='Set1',fit_reg=False, scatter_kws={"s": 70});
# Out:
# C:\Users\L01506162\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Preprocesado de datos

# %%
Gender_d=pd.get_dummies(data['Gender'])

# %%
data=pd.concat((data,Gender_d), axis=1)
data
# Out:
#                                           PLAN_INTERES      ID Gender  Age  \
# 0                           Especialidad en Innovación  274576      M   44
# 1                           Especialidad en Innovación  340962      M   43
# 2                           Especialidad en Innovación  370676      F   43
# 3                           Especialidad en Innovación  420035      M   43
# 4                           Especialidad en Innovación  434520      F   30
# ..                                                 ...     ...    ...  ...
# 144                              Maestría en Educación  601396      F   32
# 145                              Maestría en Educación  751888      F   42
# 146  Maestría en Gestión de Tecnologías de Información  345549      F   34
# 147  Maestría en Gestión de Tecnologías de Información  800322      M   41
# 148  Maestría en Gestión de Tecnologías de Información  823845      M   42
#
# ...

# %%
data.drop(['Gender'], axis=1)
# Out:
#                                           PLAN_INTERES      ID  Age  \
# 0                           Especialidad en Innovación  274576   44
# 1                           Especialidad en Innovación  340962   43
# 2                           Especialidad en Innovación  370676   43
# 3                           Especialidad en Innovación  420035   43
# 4                           Especialidad en Innovación  434520   30
# ..                                                 ...     ...  ...
# 144                              Maestría en Educación  601396   32
# 145                              Maestría en Educación  751888   42
# 146  Maestría en Gestión de Tecnologías de Información  345549   34
# 147  Maestría en Gestión de Tecnologías de Información  800322   41
# 148  Maestría en Gestión de Tecnologías de Información  823845   42
#
#     NIVEL_INTERES TIPO_PROGRAMA  MODALIDAD  OFRECIO_APOYO  POR_OFERTADO  \
# 0    Especialidad      EN LINEA  Ejecutivo              0             0
# ...

# %%
data.drop(['M'], axis=1) #0=Male 1=Female
data.rename(columns={'F':'Gender'})
# Out:
#                                           PLAN_INTERES      ID  Gender  Age  \
# 0                           Especialidad en Innovación  274576       M   44
# 1                           Especialidad en Innovación  340962       M   43
# 2                           Especialidad en Innovación  370676       F   43
# 3                           Especialidad en Innovación  420035       M   43
# 4                           Especialidad en Innovación  434520       F   30
# ..                                                 ...     ...     ...  ...
# 144                              Maestría en Educación  601396       F   32
# 145                              Maestría en Educación  751888       F   42
# 146  Maestría en Gestión de Tecnologías de Información  345549       F   34
# 147  Maestría en Gestión de Tecnologías de Información  800322       M   41
# 148  Maestría en Gestión de Tecnologías de Información  823845       M   42
#
# ...

# %%
data.drop(['Gender','M'], axis=1)
# Out:
#                                           PLAN_INTERES      ID  Age  \
# 0                           Especialidad en Innovación  274576   44
# 1                           Especialidad en Innovación  340962   43
# 2                           Especialidad en Innovación  370676   43
# 3                           Especialidad en Innovación  420035   43
# 4                           Especialidad en Innovación  434520   30
# ..                                                 ...     ...  ...
# 144                              Maestría en Educación  601396   32
# 145                              Maestría en Educación  751888   42
# 146  Maestría en Gestión de Tecnologías de Información  345549   34
# 147  Maestría en Gestión de Tecnologías de Información  800322   41
# 148  Maestría en Gestión de Tecnologías de Información  823845   42
#
#     NIVEL_INTERES TIPO_PROGRAMA  MODALIDAD  OFRECIO_APOYO  POR_OFERTADO  \
# 0    Especialidad      EN LINEA  Ejecutivo              0             0
# ...

# %%
data.rename(columns={'M':'Gender'})
# Out:
#                                           PLAN_INTERES      ID  Gender  Age  \
# 0                           Especialidad en Innovación  274576       M   44
# 1                           Especialidad en Innovación  340962       M   43
# 2                           Especialidad en Innovación  370676       F   43
# 3                           Especialidad en Innovación  420035       M   43
# 4                           Especialidad en Innovación  434520       F   30
# ..                                                 ...     ...     ...  ...
# 144                              Maestría en Educación  601396       F   32
# 145                              Maestría en Educación  751888       F   42
# 146  Maestría en Gestión de Tecnologías de Información  345549       F   34
# 147  Maestría en Gestión de Tecnologías de Información  800322       M   41
# 148  Maestría en Gestión de Tecnologías de Información  823845       M   42
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.decomposition import PCA

# %%
data.drop(['F','M'], axis=1)
# Out:
#                                           PLAN_INTERES      ID Gender  Age  \
# 0                           Especialidad en Innovación  274576      M   44
# 1                           Especialidad en Innovación  340962      M   43
# 2                           Especialidad en Innovación  370676      F   43
# 3                           Especialidad en Innovación  420035      M   43
# 4                           Especialidad en Innovación  434520      F   30
# ..                                                 ...     ...    ...  ...
# 144                              Maestría en Educación  601396      F   32
# 145                              Maestría en Educación  751888      F   42
# 146  Maestría en Gestión de Tecnologías de Información  345549      F   34
# 147  Maestría en Gestión de Tecnologías de Información  800322      M   41
# 148  Maestría en Gestión de Tecnologías de Información  823845      M   42
#
# ...
